# %% [markdown]
# Installing Packages

# %%
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# Importing the Data

# %%
df_orders = pd.read_csv('../data/raw/orders.csv')

print(df_orders.columns)
print(df_orders.shape)
df_orders.head()
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='str')
# (3421083, 7)
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                   15.00
# 2                   21.00
# 3                   29.00
# 4                   28.00

# %%
# Reading data
df_orders_products_train = pd.read_csv('../data/raw/order_products_train.csv')
print(df_orders_products_train.columns)
print(df_orders_products_train.shape)
df_orders_products_train.head()
# Out:
# Index(['order_id', 'product_id', 'add_to_cart_order', 'reordered'], dtype='str')
# (1384617, 4)
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
df_products = pd.read_csv("../data/raw/products.csv")
df_products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19    5.80
# 1             13    9.30
# 2              7    4.50
# 3              1   10.50
# 4             13    4.30

# %%
df_departments = pd.read_csv('../data/processed/departments_t.csv')
print(df_departments.columns)
print(df_departments.shape)
df_departments.head()
# Out:
# Index(['Excel', 'SQL'], dtype='str')
# (21, 2)
#    Excel      SQL
# 0      1   frozen
# 1      2    other
# 2      3   bakery
# 3      4  produce
# 4      5  alcohol

# %%
df_aisles = pd.read_csv('../data/raw/aisles.csv')
print(df_aisles.columns)
print(df_aisles.shape)
df_aisles.head()
# Out:
# Index(['aisle_id', 'aisle'], dtype='str')
# (134, 2)
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %% [markdown]
# Working with 'Orders'

# %%
pd.options.display.float_format = '{:,.2f}'.format
df_orders.describe()
# Out:
#           order_id      user_id  order_number    order_dow  order_hour_of_day  \
# count 3,421,083.00 3,421,083.00  3,421,083.00 3,421,083.00       3,421,083.00
# mean  1,710,542.00   102,978.21         17.15         2.78              13.45
# std     987,581.74    59,533.72         17.73         2.05               4.23
# min           1.00         1.00          1.00         0.00               0.00
# 25%     855,271.50    51,394.00          5.00         1.00              10.00
# 50%   1,710,542.00   102,689.00         11.00         3.00              13.00
# 75%   2,565,812.50   154,385.00         23.00         5.00              16.00
# max   3,421,083.00   206,209.00        100.00         6.00              23.00
#
#        days_since_prior_order
# count            3,214,874.00
# mean                    11.11
# std                      9.21
# min                      0.00
# 25%                      4.00
# 50%                      7.00
# 75%                     15.00
# ...

# %%
df_orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                   15.00
# 2                   21.00
# 3                   29.00
# 4                   28.00

# %%
df_orders.isna().sum()
# Out:
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# order_dow                      0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %% [markdown]
# Q1: How many unique orders exist?

# %%
df_orders["order_id"].nunique()
# Out:
# 3421083

# %%
df_orders.shape
# Out:
# (3421083, 7)

# %%
## Consistency Check: Order ID
if df_orders['order_id'].nunique() == df_orders.shape[0]:
    print('Happy')
else:
    print('Sad')
# Out:
# Happy

# %% [markdown]
# Q2: How many distinct customers are represented in the dataset?

# %%
df_orders["user_id"].nunique()
# Out:
# 206209

# %%
df_orders["order_id"].nunique()/df_orders["user_id"].nunique()
# Out:
# 16.590367054784224

# %% [markdown]
# Q3: Exploring the eval_set distribution

# %%
df_orders["eval_set"].value_counts(dropna=False)
# Out:
# eval_set
# prior    3214874
# train     131209
# test       75000
# Name: count, dtype: int64

# %%
df_dow = df_orders["order_dow"].value_counts().reset_index()
df_dow
# Out:
#    order_dow   count
# 0          0  600905
# 1          1  587478
# 2          2  467260
# 3          5  453368
# 4          6  448761
# 5          3  436972
# 6          4  426339

# %%
df_dow.sort_values('order_dow')
# Out:
#    order_dow   count
# 0          0  600905
# 1          1  587478
# 2          2  467260
# 5          3  436972
# 6          4  426339
# 3          5  453368
# 4          6  448761

# %%
df_dow.to_csv('../data/processed/dow.csv', index=False)

# %%
df_ohod = df_orders['order_hour_of_day'].value_counts().reset_index().sort_values('order_hour_of_day')
df_ohod.head()
# Out:
#     order_hour_of_day  count
# 18                  0  22758
# 19                  1  12398
# 21                  2   7539
# 23                  3   5474
# 22                  4   5527

# %%
#import sys
#print(sys.executable)

# %%
#!pip show openpyxl

# %%
#!pip install openpyxl

# %%
df_ohod.to_excel('../data/processed/ohod.xlsx', index = False)

# %%
df_orders.loc[df_orders["order_number"] == 1, "days_since_prior_order"].isna().all()
# Out:
# np.True_

# %%
needed_columns = ['days_since_prior_order', 'order_number', 'user_id']

# %%
#df_orders[['days_since_prior_order', 'order_number']].head()
#df_first_orders = df_orders[needed_columns][df_orders['order_number'] == 1]
#print(df_first_orders.head())
#df_first_orders.reset_index(inplace=True)
#df_first_orders.head()

# %%
df_first_orders = df_orders[needed_columns][df_orders['order_number'] == 1].reset_index()
#df_first_orders.drop(columns='index', inplace=True)
df_first_orders = df_first_orders.drop(columns='index')

# %%
df_orders.iloc[26]
# Out:
# order_id                  1374495
# user_id                         3
# eval_set                    prior
# order_number                    1
# order_dow                       1
# order_hour_of_day              14
# days_since_prior_order        NaN
# Name: 26, dtype: object

# %%
if df_orders["order_id"].is_unique:
    print('Happy')
# Out:
# Happy

# %%
df_orders["order_dow"].between(0, 6).all()
# Out:
# np.True_

# %%
df_orders["order_hour_of_day"].between(0, 23).all()
# Out:
# np.True_

# %%
df_orders_train = df_orders[df_orders["eval_set"] == "train"]
df_orders_train.head()
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 10   1187899        1    train            11          4                  8
# 25   1492625        2    train            15          1                 11
# 49   2196797        5    train             5          0                 11
# 74    525192        7    train            21          2                 11
# 78    880375        8    train             4          1                 14
#
#     days_since_prior_order
# 10                   14.00
# 25                   30.00
# 49                    6.00
# 74                    6.00
# 78                   10.00

# %%
df_orders_train.shape
# Out:
# (131209, 7)

# %%
# Since the further analysis is going to be done based on the subset where eval_set == 'Train'
#del df_orders

# %%
df_orders_products_train["reordered"].value_counts(normalize=False)
# Out:
# reordered
# 1    828824
# 0    555793
# Name: count, dtype: int64

# %%
df_orders_products_train["reordered"].value_counts(normalize=True)
# Out:
# reordered
# 1   0.60
# 0   0.40
# Name: proportion, dtype: float64

# %%
df_orders_products_train["add_to_cart_order"].describe()
# Out:
# count   1,384,617.00
# mean            8.76
# std             7.42
# min             1.00
# 25%             3.00
# 50%             7.00
# 75%            12.00
# max            80.00
# Name: add_to_cart_order, dtype: float64

# %%
10 > 8 > 3
# Out:
# True

# %%
atr = 8/10
atr
# Out:
# 0.8

# %%
br = 3/10
br
# Out:
# 0.3

# %%
df_orders_products_train.head(10)
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1
# 5         1       13176                  6          0
# 6         1       47209                  7          0
# 7         1       22035                  8          1
# 8        36       39612                  1          0
# 9        36       19660                  2          1

# %%
df_orders_products_train["order_id"].is_unique
# Out:
# False

# %%
#add to cart order is one
df_orders_first_atc = df_orders_products_train[df_orders_products_train['add_to_cart_order']==1]
df_orders_first_atc.shape
# Out:
# (131209, 4)

# %%
df_orders_first_atc['product_id'].value_counts()
# Out:
# product_id
# 24852    4605
# 13176    3889
# 27845    1144
# 47766     995
# 21137     900
#          ...
# 7044        1
# 28344       1
# 40866       1
# 13539       1
# 40800       1
# Name: count, Length: 17908, dtype: int64

# %%
df_products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19    5.80
# 1             13    9.30
# 2              7    4.50
# 3              1   10.50
# 4             13    4.30

# %%
df_products.shape
# Out:
# (49693, 5)

# %%
df_products.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49693 entries, 0 to 49692
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49693 non-null  int64
#  1   product_name   49677 non-null  str
#  2   aisle_id       49693 non-null  int64
#  3   department_id  49693 non-null  int64
#  4   prices         49693 non-null  float64
# dtypes: float64(1), int64(3), str(1)
# memory usage: 3.4 MB

# %%
df_products.describe()
# Out:
#        product_id  aisle_id  department_id    prices
# count   49,693.00 49,693.00      49,693.00 49,693.00
# mean    24,844.35     67.77          11.73      9.99
# std     14,343.72     38.32           5.85    453.52
# min          1.00      1.00           1.00      1.00
# 25%     12,423.00     35.00           7.00      4.10
# 50%     24,845.00     69.00          13.00      7.10
# 75%     37,265.00    100.00          17.00     11.20
# max     49,688.00    134.00          21.00 99,999.00

# %%
df_products.isna().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
df_products[df_products['product_name'].isna()==True]
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14   12.20
# 68             69          NaN        26              7   11.80
# 115           116          NaN        93              3   10.80
# 261           262          NaN       110             13   12.10
# 525           525          NaN       109             11    1.20
# 1511         1511          NaN        84             16   14.30
# 1780         1780          NaN       126             11   12.30
# 2240         2240          NaN        52              1   14.20
# 2586         2586          NaN       104             13   12.40
# 3159         3159          NaN       126             11   13.10
# 3230         3230          NaN       120             16   14.40
# 3736         3736          NaN        41              8   14.80
# 4283         4283          NaN        77              7   14.40
# 4790         4790          NaN        91             16   14.50
# ...

# %%
#24852  - Banana
df_products[df_products['product_id'] == 24852]
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 24853       24852       Banana        24              4   12.30

# %%
#13176 - Bag of Organic Bananas
df_products[df_products['product_id'] == 13176]
# Out:
#        product_id            product_name  aisle_id  department_id  prices
# 13176       13176  Bag of Organic Bananas        24              4   10.30

# %%
# max price
df_products.sort_values(by='prices', ascending=False).head(1)
# Out:
#        product_id           product_name  aisle_id  department_id    prices
# 33666       33664  2 % Reduced Fat  Milk        84             16 99,999.00

# %%
df_products["product_id"].nunique()
# Out:
# 49686

# %%
df_products.shape
# we have duplicates
# Out:
# (49693, 5)

# %%
df_departments.head()
# somewhere we changed the columns name, but the Excel = department_id and SQL = department
# Out:
#    Excel      SQL
# 0      1   frozen
# 1      2    other
# 2      3   bakery
# 3      4  produce
# 4      5  alcohol

# %%
df_departments = df_departments.rename(columns={
    'Excel': 'department_id',
    'SQL': 'department'
})

# %%
df_departments.shape
# Out:
# (21, 2)

# %%
df_aisles.head()
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
df_aisles.shape
# Out:
# (134, 2)

# %%
df_aisles.head()
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
df_products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19    5.80
# 1             13    9.30
# 2              7    4.50
# 3              1   10.50
# 4             13    4.30

# %%
#pd.merge(left_df, right_df, on="key_column", how="left")
df_products_aisles = pd.merge(df_products, df_aisles,
                              on="aisle_id",
                              how="left", indicator=True)

# %%
df_products_aisles.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices                       aisle _merge
# 0             19    5.80               cookies cakes   both
# 1             13    9.30           spices seasonings   both
# 2              7    4.50                         tea   both
# 3              1   10.50                frozen meals   both
# 4             13    4.30  marinades meat preparation   both

# %%
print(df_products_aisles.columns)
# Out:
# Index(['product_id', 'product_name', 'aisle_id', 'department_id', 'prices',
#        'aisle', '_merge'],
#       dtype='str')

# %%
print(df_departments.columns)
# Out:
# Index(['department_id', 'department'], dtype='str')

# %%
df_products_aisles['_merge'].value_counts()
# Out:
# _merge
# both          49693
# left_only         0
# right_only        0
# Name: count, dtype: int64

# %%
df_products_aisles_department = pd.merge(df_products_aisles, df_departments, 
                                         on='department_id',
                                         how='left')

# %%
df_products_aisles_department.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices                       aisle _merge department
# 0             19    5.80               cookies cakes   both     snacks
# 1             13    9.30           spices seasonings   both     pantry
# 2              7    4.50                         tea   both  beverages
# 3              1   10.50                frozen meals   both     frozen
# 4             13    4.30  marinades meat preparation   both     pantry

# %%
#df_products_aisles_department.drop(columns = ['aisle_id', 'department_id'], inplace=True)
#df_products_aisles.drop(columns = ['_merge'])

# %%
df_products_aisles_department.drop(columns = ['_merge'], inplace=True)

# %%
df_products_aisles_department.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices                       aisle department
# 0             19    5.80               cookies cakes     snacks
# 1             13    9.30           spices seasonings     pantry
# 2              7    4.50                         tea  beverages
# 3              1   10.50                frozen meals     frozen
# 4             13    4.30  marinades meat preparation     pantry

# %%
#del df_departments
#del df_products
#del df_aisles

# %%
df_products_aisles_department['department'].value_counts()
# Out:
# department
# personal care      6565
# snacks             6264
# pantry             5371
# beverages          4365
# frozen             4007
# dairy eggs         3449
# household          3085
# canned goods       2092
# dry goods pasta    1858
# produce            1684
# bakery             1516
# deli               1322
# missing            1258
# international      1139
# breakfast          1116
# babies             1081
# alcohol            1056
# pets                972
# meat seafood        907
# other               548
# bulk                 38
# Name: count, dtype: int64

# %%
import pandas as pd
URL_CUSTOMERS = 'https://raw.githubusercontent.com/hovhannisyan91/data_analytics_with_python/refs/heads/main/data/raw/customers.csv'
URL_STATES = 'https://raw.githubusercontent.com/hovhannisyan91/data_analytics_with_python/refs/heads/main/data/raw/states.csv'

# %%
URLS = {
    'customers.csv': URL_CUSTOMERS,
    'state.csv': URL_STATES}

# %%
for i in URLS.items():
    print(f'file name {i[0]} \n file path: {i[1]}')
# Out:
# file name customers.csv
#  file path: https://raw.githubusercontent.com/hovhannisyan91/data_analytics_with_python/refs/heads/main/data/raw/customers.csv
# file name state.csv
#  file path: https://raw.githubusercontent.com/hovhannisyan91/data_analytics_with_python/refs/heads/main/data/raw/states.csv

# %%
for i in URLS.items():
    print(f'Downloading {i[0]}')
    df = pd.read_csv(i[1])
    df.to_csv(f'../data/downloads/{i[0]}')
    print(f'saving {i} in [../data/downloads]')

print('The job is done')
# Out:
# ...
# saving ('customers.csv', 'https://raw.githubusercontent.com/hovhannisyan91/data_analytics_with_python/refs/heads/main/data/raw/customers.csv') in [../data/downloads]
# ...
# saving ('state.csv', 'https://raw.githubusercontent.com/hovhannisyan91/data_analytics_with_python/refs/heads/main/data/raw/states.csv') in [../data/downloads]
# The job is done

# %%
df_customers = pd.read_csv(URL_CUSTOMERS)
df_customers.shape
# Out:
# (206209, 10)

# %%
df_customers.to_csv('../data/raw/customer.csv')
df_customers.head()
# Out:
#    user_id First Name   Surname  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df_states = pd.read_csv(URL_STATES)
df_states.head()
# Out:
#            state     region     division
# 0    Connecticut  Northeast  New England
# 1          Maine  Northeast  New England
# 2  Massachusetts  Northeast  New England
# 3  New Hampshire  Northeast  New England
# 4   Rhode Island  Northeast  New England

# %%
df_states.to_csv("../data/raw/states.csv")

# %%
df_customers = df_customers.rename(columns={"STATE": "state"})

# %%
df_customers.head()
# Out:
#    user_id First Name   Surname  Gender       state  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df_products_departments = pd.merge(df_products, df_departments, on="department_id", how="left")

# %%
df_products_departments.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices department
# 0             19    5.80     snacks
# 1             13    9.30     pantry
# 2              7    4.50  beverages
# 3              1   10.50     frozen
# 4             13    4.30     pantry

# %%
df_products_departments.drop(columns=['department_id'], inplace=True)

# %%
df_products_enriched = pd.merge(df_products_departments, df_aisles, on="aisle_id", how="left")

# %%
df_products_enriched.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    prices department                       aisle
# 0    5.80     snacks               cookies cakes
# 1    9.30     pantry           spices seasonings
# 2    4.50  beverages                         tea
# 3   10.50     frozen                frozen meals
# 4    4.30     pantry  marinades meat preparation

# %%
df_products_enriched.drop(columns=['aisle_id'], inplace=True)

# %%
df_train_transactions = pd.merge(df_orders, df_orders_products_train, on="order_id", how="inner")

# %%
df_train_transactions.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   1187899        1    train            11          4                  8
# 1   1187899        1    train            11          4                  8
# 2   1187899        1    train            11          4                  8
# 3   1187899        1    train            11          4                  8
# 4   1187899        1    train            11          4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                   14.00         196                  1          1
# 1                   14.00       25133                  2          1
# 2                   14.00       38928                  3          1
# 3                   14.00       26405                  4          1
# 4                   14.00       39657                  5          1

# %%
df_train_analytic = pd.merge(df_train_transactions, df_products_enriched, on="product_id", how="left", indicator=True)

# %%
df_train_analytic.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   1187899        1    train            11          4                  8
# 1   1187899        1    train            11          4                  8
# 2   1187899        1    train            11          4                  8
# 3   1187899        1    train            11          4                  8
# 4   1187899        1    train            11          4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                   14.00         196                  1          1
# 1                   14.00       25133                  2          1
# 2                   14.00       38928                  3          1
# 3                   14.00       26405                  4          1
# 4                   14.00       39657                  5          1
#
#                        product_name  prices  department            aisle  \
# ...

# %%
df_train_analytic.drop(columns=['eval_set','product_id','_merge'], inplace=True)

# %%
df_train_analytic.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1187899        1            11          4                  8
# 1   1187899        1            11          4                  8
# 2   1187899        1            11          4                  8
# 3   1187899        1            11          4                  8
# 4   1187899        1            11          4                  8
#
#    days_since_prior_order  add_to_cart_order  reordered  \
# 0                   14.00                  1          1
# 1                   14.00                  2          1
# 2                   14.00                  3          1
# 3                   14.00                  4          1
# 4                   14.00                  5          1
#
#                        product_name  prices  department            aisle
# 0                              Soda    9.00   beverages      soft drinks
# 1             Organic String Cheese    8.60  dairy eggs  packaged cheese
# ...

# %%
df_train_analytic.shape
# Out:
# (1384706, 12)

# %%
df_customers_states = pd.merge(df_customers, df_states, on="state", how="left")
df_customers_states.head()
# Out:
#    user_id First Name   Surname  Gender       state  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income   region            division
# 0             3    married  165665  Midwest  West North Central
# 1             0     single   59285     West            Mountain
# 2             2    married   99568     West            Mountain
# 3             0     single   42049  Midwest  West North Central
# 4             1    married   40374    South      South Atlantic

# %%
df_train_analytic_final = pd.merge(df_train_analytic, df_customers_states, on="user_id", how="left")
df_train_analytic_final.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1187899        1            11          4                  8
# 1   1187899        1            11          4                  8
# 2   1187899        1            11          4                  8
# 3   1187899        1            11          4                  8
# 4   1187899        1            11          4                  8
#
#    days_since_prior_order  add_to_cart_order  reordered  \
# 0                   14.00                  1          1
# 1                   14.00                  2          1
# 2                   14.00                  3          1
# 3                   14.00                  4          1
# 4                   14.00                  5          1
#
#                        product_name  prices  ... Surname  Gender    state Age  \
# 0                              Soda    9.00  ...  Nguyen  Female  Alabama  31
# ...

# %%
df_train_analytic_final.drop(columns=['user_id'], inplace=True)
df_train_analytic_final.head()
# Out:
#    order_id  order_number  order_dow  order_hour_of_day  \
# 0   1187899            11          4                  8
# 1   1187899            11          4                  8
# 2   1187899            11          4                  8
# 3   1187899            11          4                  8
# 4   1187899            11          4                  8
#
#    days_since_prior_order  add_to_cart_order  reordered  \
# 0                   14.00                  1          1
# 1                   14.00                  2          1
# 2                   14.00                  3          1
# 3                   14.00                  4          1
# 4                   14.00                  5          1
#
#                        product_name  prices  department  ... Surname  Gender  \
# 0                              Soda    9.00   beverages  ...  Nguyen  Female
# 1             Organic String Cheese    8.60  dairy eggs  ...  Nguyen  Female
# ...

# %%
df_train_analytic_final.shape
# Out:
# (1384706, 22)

# %%
df_train_analytic_final.to_csv("../data/processed/train_analytic_final.csv")

# %%
#import sys
#print(sys.executable)

# %%
#import sys
#!{sys.executable} -m pip install pyarrow

# %%
df_train_analytic_final.to_parquet("../data/processed/instacart.parquet", index = False)
