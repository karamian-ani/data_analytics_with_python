# %%
from templates import *
from templates import my_bar_plot

# %%
df = pd.read_csv("../data//ab_testing/fast_food.csv")
#df.head()

# %%
df.rename(columns={"MarketSize": "market size", "SalesInThousands": "sales"}, inplace=True)
#df.head()

# %%
my_bar_plot(df, "market size", "sales", True)
