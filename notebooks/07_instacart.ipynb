# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#import instacart.csv/par

df_instacart = pd.read_parquet("../data/processed/instacart.parquet")
df_instacart.head()
# Out:
#    order_id  order_number  order_dow  order_hour_of_day  \
# 0   1187899            11          4                  8
# 1   1187899            11          4                  8
# 2   1187899            11          4                  8
# 3   1187899            11          4                  8
# 4   1187899            11          4                  8
#
#    days_since_prior_order  add_to_cart_order  reordered  \
# 0                    14.0                  1          1
# 1                    14.0                  2          1
# 2                    14.0                  3          1
# 3                    14.0                  4          1
# 4                    14.0                  5          1
#
#                        product_name  prices  department  ... Surname  Gender  \
# 0                              Soda     9.0   beverages  ...  Nguyen  Female
# 1             Organic String Cheese     8.6  dairy eggs  ...  Nguyen  Female
# 2          0% Greek Strained Yogurt    12.6  dairy eggs  ...  Nguyen  Female
# 3  XL Pick-A-Size Paper Towel Rolls     1.0   household  ...  Nguyen  Female
# 4            Milk Chocolate Almonds     6.8      snacks  ...  Nguyen  Female
#
#      state Age date_joined  n_dependants fam_status  income region  \
# 0  Alabama  31   2/17/2019             3    married   40423  South
# 1  Alabama  31   2/17/2019             3    married   40423  South
# 2  Alabama  31   2/17/2019             3    married   40423  South
# 3  Alabama  31   2/17/2019             3    married   40423  South
# 4  Alabama  31   2/17/2019             3    married   40423  South
#
#              division
# 0  East South Central
# 1  East South Central
# 2  East South Central
# 3  East South Central
# 4  East South Central
#
# [5 rows x 22 columns]

# %%
df_instacart.shape
# Out:
# (1384706, 22)

# %%
df_instacart.describe()
# Out:
#            order_id  order_number     order_dow  order_hour_of_day  \
# count  1.384706e+06  1.384706e+06  1.384706e+06       1.384706e+06
# mean   1.706298e+06  1.709135e+01  2.701394e+00       1.357761e+01
# std    9.897342e+05  1.661400e+01  2.167637e+00       4.238461e+00
# min    1.000000e+00  4.000000e+00  0.000000e+00       0.000000e+00
# 25%    8.433700e+05  6.000000e+00  1.000000e+00       1.000000e+01
# 50%    1.701880e+06  1.100000e+01  3.000000e+00       1.400000e+01
# 75%    2.568023e+06  2.100000e+01  5.000000e+00       1.700000e+01
# max    3.421070e+06  1.000000e+02  6.000000e+00       2.300000e+01
#
#        days_since_prior_order  add_to_cart_order     reordered        prices  \
# count            1.384706e+06       1.384706e+06  1.384706e+06  1.384618e+06
# mean             1.706626e+01       8.758180e+00  5.985964e-01  1.411711e+01
# std              1.042639e+01       7.423973e+00  4.901825e-01  6.802253e+02
# min              0.000000e+00       1.000000e+00  0.000000e+00  1.000000e+00
# 25%              7.000000e+00       3.000000e+00  0.000000e+00  4.300000e+00
# 50%              1.500000e+01       7.000000e+00  1.000000e+00  7.400000e+00
# 75%              3.000000e+01       1.200000e+01  1.000000e+00  1.130000e+01
# max              3.000000e+01       8.000000e+01  1.000000e+00  9.999900e+04
#
#                 Age  n_dependants        income
# count  1.384706e+06  1.384706e+06  1.384706e+06
# mean   4.938182e+01  1.498778e+00  9.766228e+04
# std    1.843685e+01  1.117567e+00  4.199139e+04
# min    1.800000e+01  0.000000e+00  2.591100e+04
# 25%    3.300000e+01  0.000000e+00  6.485900e+04
# 50%    4.900000e+01  1.000000e+00  9.576500e+04
# 75%    6.500000e+01  2.000000e+00  1.268178e+05
# max    8.100000e+01  3.000000e+00  5.910890e+05

# %%
# Data preparation
orders_by_dow = (df_instacart[['order_id', 'order_dow']]
                 .drop_duplicates()
                 .groupby('order_dow')
                 .size()
                 )
type(orders_by_dow)
# Out:
# pandas.Series

# %%
d = pd.DataFrame(orders_by_dow).reset_index()
d
# Out:
#    order_dow      0
# 0          0  27465
# 1          1  19672
# 2          2  16119
# 3          3  15687
# 4          4  15959
# 5          5  17406
# 6          6  18901

# %%
d.columns
# Out:
# Index(['order_dow', 0], dtype='object')

# %%
d.rename(columns={0:'number_of_orders'},inplace=True)
d
# Out:
#    order_dow  number_of_orders
# 0          0             27465
# 1          1             19672
# 2          2             16119
# 3          3             15687
# 4          4             15959
# 5          5             17406
# 6          6             18901

# %%
plt.Figure()
plt.bar(orders_by_dow.index,orders_by_dow.values)
plt.title('Number of orders by Day of Week')
plt.xlabel('Day of Week')
plt.ylabel('Number of Orders')
plt.show()
