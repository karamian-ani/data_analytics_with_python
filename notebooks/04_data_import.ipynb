# %%
## Unzipping File

##import zipfile
##with zipfile.ZipFile("../data/raw/Archive.zip", "r") as zip_ref:
##    zip_ref.extractall("../data/raw")

# %%
## Import packages
import pandas as pd

# %%
## Reading data
df_orders = pd.read_csv('../data/raw/orders.csv',
                       # usecols=['order_id', 'user_id', 'order_hour_of_day', 'days_since_prior_order'])
                        )
df_orders.head(5)
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_orders.tail(5)
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 3421078                 18                    29.0
# 3421079                 10                    30.0
# 3421080                 12                    18.0
# 3421081                 12                     7.0
# 3421082                 14                    30.0

# %%
df_orders.shape
# Out:
# (3421083, 7)

# %%
print(type(df_orders.shape))
print(f" Tha # of rows {df_orders.shape[0]} \n The # of columns {df_orders.shape[1]}")
# Out:
# <class 'tuple'>
#  Tha # of rows 3421083
#  The # of columns 7

# %%
## List of column
df_orders.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='str')

# %%
df_orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                str
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), str(1)
# memory usage: 182.7 MB

# %%
df_orders.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# eval_set                      str
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
df_orders.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# ...

# %%
df_orders.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='str')

# %%
df_orders.drop(columns = ['eval_set'], inplace = True)

# %%
df_orders.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day',
#        'days_since_prior_order'],
#       dtype='str')

# %%
df_orders_new = df_orders.rename(columns={'order_number' : 'order_n'})
df_orders_new.head(5)
# Out:
#    order_id  user_id  order_n  order_dow  order_hour_of_day  \
# 0   2539329        1        1          2                  8
# 1   2398795        1        2          3                  7
# 2    473747        1        3          3                 12
# 3   2254736        1        4          4                  7
# 4    431534        1        5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_orders_new.columns
# Out:
# Index(['order_id', 'user_id', 'order_n', 'order_dow', 'order_hour_of_day',
#        'days_since_prior_order'],
#       dtype='str')

# %%
df_orders_new = df_orders_new.assign(
    is_weekend = df_orders_new["order_dow"].isin([0,6]),
    is_morning = df_orders_new["order_hour_of_day"]<12,
    #is_premium = df_orders_new["days_since_prior_order"] <=7
)

# %%
df_orders_new.head(5)
# Out:
#    order_id  user_id  order_n  order_dow  order_hour_of_day  \
# 0   2539329        1        1          2                  8
# 1   2398795        1        2          3                  7
# 2    473747        1        3          3                 12
# 3   2254736        1        4          4                  7
# 4    431534        1        5          4                 15
#
#    days_since_prior_order  is_weekend  is_morning
# 0                     NaN       False        True
# 1                    15.0       False        True
# 2                    21.0       False       False
# 3                    29.0       False        True
# 4                    28.0       False       False

# %%
del df_orders

# %%
df_orders_new['days_since_prior_order'] = df_orders_new['days_since_prior_order'].fillna(0)

# %%
df_orders_new.head(5)
# Out:
#    order_id  user_id  order_n  order_dow  order_hour_of_day  \
# 0   2539329        1        1          2                  8
# 1   2398795        1        2          3                  7
# 2    473747        1        3          3                 12
# 3   2254736        1        4          4                  7
# 4    431534        1        5          4                 15
#
#    days_since_prior_order  is_weekend  is_morning
# 0                     0.0       False        True
# 1                    15.0       False        True
# 2                    21.0       False       False
# 3                    29.0       False        True
# 4                    28.0       False       False

# %%
#174MB with index and boolean column (0-N)
#146MB w/o index
#153MB with index w/o boolean
df_orders_new.to_csv('../data/processed/orders.csv' ,index=False)

# %%
df_products = pd.read_csv('../data/raw/products.csv')
df_products.head(5)
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_products.shape
# Out:
# (49693, 5)

# %%
df_products.drop(columns=['aisle_id'], inplace = True)

# %%
df_departments = pd.read_csv('../data/raw/departments.csv')

# %%
df_departments.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
df_temp_t = df_departments.T
df_temp_t.head()
# Out:
#                         0
# department_id  department
# 1                  frozen
# 2                   other
# 3                  bakery
# 4                 produce

# %%
df_temp_t.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 22 entries, department_id to 21
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       22 non-null     str
# dtypes: str(1)
# memory usage: 908.0+ bytes

# %%
df_temp_t.reset_index(inplace=True)

# %%
df_temp_t.head()
# Out:
#            index           0
# 0  department_id  department
# 1              1      frozen
# 2              2       other
# 3              3      bakery
# 4              4     produce

# %%
col_names = df_temp_t.iloc[0]
col_names
# Out:
# index    department_id
# 0           department
# Name: 0, dtype: str

# %%
department_main_data = df_temp_t.iloc[1:]
department_main_data.head()
# Out:
#   index        0
# 1     1   frozen
# 2     2    other
# 3     3   bakery
# 4     4  produce
# 5     5  alcohol

# %%
department_main_data.columns = ['Excel', 'SQL']
col_names
# Out:
# index    department_id
# 0           department
# Name: 0, dtype: str

# %%
department_main_data.head()
# Out:
#   Excel      SQL
# 1     1   frozen
# 2     2    other
# 3     3   bakery
# 4     4  produce
# 5     5  alcohol

# %%
##df_orders.to_csv("../data/processed/orders_cleaned.csv", index=False)

# %%
df_products.to_csv("../data/processed/products_cleaned.csv", index=False)

# %%
department_main_data.to_csv("../data/processed/departments_t.csv", index=False)
