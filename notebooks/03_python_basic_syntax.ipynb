# %%
r = 1500
t = 0.2

total = r * (1+t)
total
# Out:
# 1800.0

# %%
2**3
# Out:
# 8

# %%
2!=3
# Out:
# True

# %%
(10>5) and (10<5)
# Out:
# False

# %%
l = [10,20,30,40]

# %%
l[-1]
# Out:
# 40

# %%
len(l)
# Out:
# 4

# %%
l.append (50)
l
# Out:
# [10, 20, 30, 40, 50, 50, 50]

# %%
l = [10, 'test', 'mest', 40]

# %%
l[-2]
# Out:
# 'mest'
