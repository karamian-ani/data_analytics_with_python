# %% [markdown]
# Arithmetic Operation

# %%
r = 1500
t = 0.2

total = r * (1+t)
total
# Out:
# 1800.0

# %%
2**3
# Out:
# 8

# %%
2!=3
# Out:
# True

# %% [markdown]
# And or Not

# %%
(10>5) or (10<5)
# Out:
# True

# %%
(10>5) and (10<5)
# Out:
# False

# %% [markdown]
# List

# %%
l = [10,20,30,40]
l
# Out:
# [10, 20, 30, 40]

# %%
l.append (50)
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l[0] = 11
l
# Out:
# [11, 20, 30, 40]

# %%
l = [10,'test1234', 'mest', [40,10], 123]
l
# Out:
# [10, 'test1234', 'mest', [40, 10], 123]

# %%
l[0]
# Out:
# 10

# %%
l[-1]
# Out:
# 123

# %%
len(l)
# Out:
# 5

# %%
l = [10, 'test', 'mest', 40]
l
# Out:
# [10, 'test', 'mest', 40]

# %%
l[-2]
# Out:
# 'mest'

# %%
l = ['data1.csv', 'data2.csv', 'data3.csv']

# %% [markdown]
# Tuple

# %%
t = (10, 12, 13)

# %% [markdown]
# Set

# %%
my_list = [1, 2, 3, 4, 5, 5, 5, 5, 5,5]
my_list
# Out:
# [1, 2, 3, 4, 5, 5, 5, 5, 5, 5]

# %%
my_set = set (my_list)
my_set
# Out:
# {1, 2, 3, 4, 5}

# %%
a = {1,2,3,4,5}
b = {4,5,6,7,8}

# %%
a.intersection(b)
# Out:
# {4, 5}

# %% [markdown]
# Dictionary

# %%
# key value pairs
customers = {
            'Alice': 25,
            'Bob': 30,
            'Charlie': 35
            }

# %%
customers['Alice']=30

# %%
customers
# Out:
# {'Alice': 30, 'Bob': 30, 'Charlie': 35}

# %%
customer = {'name': 'Alice', 'age': 30, 'city':'New York'}
customer['State'] ='NY'
customer['Segment'] ='Premium'

# %%
customer1 = customer
customer1
# Out:
# {'name': 'Alice',
#  'age': 30,
#  'city': 'New York',
#  'State': 'NY',
#  'Segment': 'Premium'}

# %%
#Bob
customer2 = {'name': 'Bob', 'age': 25, 'city':'Los Angeles', 'State': 'CA', 'Segment':'Standard'}

# %%
#Armen
customer3 = {'name': 'Charlie', 'age': 28, 'city':'Chicago', 'State': 'IL'}

# %%
list_of_customers = [customer1, customer2, customer3]

# %%
list_of_customers
# Out:
# [{'name': 'Alice',
#   'age': 30,
#   'city': 'New York',
#   'State': 'NY',
#   'Segment': 'Premium'},
#  {'name': 'Bob',
#   'age': 25,
#   'city': 'Los Angeles',
#   'State': 'CA',
#   'Segment': 'Standard'},
#  {'name': 'Charlie', 'age': 28, 'city': 'Chicago', 'State': 'IL'}]

# %%
list_of_customers[0].keys()
# Out:
# dict_keys(['name', 'age', 'city', 'State', 'Segment'])

# %%
l = [10,20,30,40]
d = {'key', 'Value'}

# %% [markdown]
# Pandas

# %%
import pandas as pd

# %%
data = {'name': ['Alice', 'Bob', 'Charlie', 'Armen', 'David'],
        'age': [30, 25, 28, 35, 42],
        'city': ['New York', 'Los Angeles', 'Chicago', 'Boston', 'San Francisco'],
        'revenue': [10000, 15000, 12000, 20000, 18000],
        'segment': ['Premium', 'Premium', 'Premium', 'Standard','Premium']}

# %%
data ['name']
data ['age']
# Out:
# [30, 25, 28, 35, 42]

# %%
df = pd.DataFrame(data)

# %%
df_filtered=df[df['age']>30]
df_filtered
# Out:
#     name  age           city
# 3  Armen   35         Boston
# 4  David   42  San Francisco

# %%
df.loc[df['revenue']>15000, 'segment']='High Revenue'

# %%
df.head()
# Out:
#       name  age           city  revenue       segment
# 0    Alice   30       New York    10000       Premium
# 1      Bob   25    Los Angeles    15000       Premium
# 2  Charlie   28        Chicago    12000       Premium
# 3    Armen   35         Boston    20000  High Revenue
# 4    David   42  San Francisco    18000  High Revenue

# %% [markdown]
# If

# %%
revenue = 150

if revenue > 100:
    print("High revenue")
else:
    print("Normal revenue")
# Out:
# High revenue

# %%
revenue = 90

if revenue > 100:
    print("High revenue")
else:
    print("Normal revenue")
# Out:
# Normal revenue

# %%
revenue = 120
print("Analysis complete")
if revenue > 100:
    print("High revenue")
    print(f"Because the revenue is {revenue}")
else:
    print("low revenue")
# Out:
# Analysis complete
# High revenue
# Because the revenue is 120

# %%
revenue = 210

if revenue > 200:
    print(f"Very high revenue: {revenue}")
elif revenue > 100:
    print(f"High revenue: {revenue}")
elif revenue > 50:
    print(f"Medium revenue: {revenue}")
else:
    print(f"Low revenue: {revenue}")
# Out:
# Very high revenue: 210

# %%
b = 5
a = 6

# %%
a = b
a
# Out:
# 5

# %%
a == b
# Out:
# True

# %%
revenue = 150
is_active = True

if revenue > 100 and True:
    print("Target customer")
# Out:
# Target customer

# %%
if is_active:
    print("Customer is active")
# Out:
# Customer is active

# %%
is_active = False

if not is_active:
    print("Customer is inactive")
# Out:
# Customer is inactive

# %% [markdown]
# Swap a & b

# %%
a = 6
b = 5

# %%
c = a
a = b
b = c

# %%
print (a)
# Out:
# 5

# %%
print (b)
# Out:
# 6

# %%
a = a + b

# %%
b = a - b
a = a - b

# %%
print (f" a is equal to: {a} \n b is equal to: {b}")
# Out:
#  a is equal to: 6
#  b is equal to: 5

# %% [markdown]
# Loops

# %%
list_of_data_sources = ['data1.csv', 'data2.csv', 'data3,csv' ]

# %%
for i in list_of_data_sources:
    print(f'then name of current data source is: {i}')
print ('Exit loop')
# Out:
# then name of current data source is: data1.csv
# then name of current data source is: data2.csv
# then name of current data source is: data3,csv
# Exit loop

# %%
number_of_clicks = 0

for i in range(5):
    number_of_clicks = i + 1

number_of_clicks
# Out:
# 5

# %%
sales = [100, 200, 150]

total = 0

for value in sales:
    total = total + value

total
# Out:
# 450

# %%
sales = [100, 200, 150, 50]

for value in sales:
    if value > 120:
        print("High sale:", value)
    else:
        print("low sale:" , value)
# Out:
# low sale: 100
# High sale: 200
# High sale: 150
# low sale: 50

# %%
customer = {
    "name": "Anna",
    "revenue": 150,
    "city": "Yerevan"
}

# %%
customer.keys()
customer['name']
# Out:
# 'Anna'

# %%
customer['city']
# Out:
# 'Yerevan'

# %%
customer['revenue']
# Out:
# 150

# %%
customer = {
    "name": ["Anna", "Gagik"],
    "revenue": [150, 200],
    "city": ["Yerevan", "Avan"]
}

customer
customer.keys()
customer.values()
# Out:
# dict_values([['Anna', 'Gagik'], [150, 200], ['Yerevan', 'Avan']])

# %%
customer.items()
# Out:
# dict_items([('name', ['Anna', 'Gagik']), ('revenue', [150, 200]), ('city', ['Yerevan', 'Avan'])])

# %%
for key, value in customer.items():
    print(key, ":", customer[key])
# Out:
# name : ['Anna', 'Gagik']
# revenue : [150, 200]
# city : ['Yerevan', 'Avan']

# %%
list(customer.values())[0]
# Out:
# ['Anna', 'Gagik']

# %%
type(customer.values())
# Out:
# dict_values

# %%
customer.items()
# Out:
# dict_items([('name', ['Anna', 'Gagik']), ('revenue', [150, 200]), ('city', ['Yerevan', 'Avan'])])

# %%
for key,value in customer.items():
    print (key)
    print(key, ":", customer[key][1])
# Out:
# name
# name : Gagik
# revenue
# revenue : 200
# city
# city : Avan

# %%
l = [10, 20, 30, 40, 50]

# %%
for i in range(len(l)):
    print(l[i])
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
for i in l[3:]:
    print(i)
# Out:
# 40
# 50

# %%
l[:3]
# Out:
# [10, 20, 30]

# %%
t = ('name', 'Anna')
