# %% [markdown]
# Arithmetic Operation

# %%
r = 1500
t = 0.2

total = r * (1+t)
total
# Out:
# 1800.0

# %%
2**3
# Out:
# 8

# %%
2!=3
# Out:
# True

# %% [markdown]
# And or Not

# %%
(10>5) or (10<5)
# Out:
# True

# %%
(10>5) and (10<5)
# Out:
# False

# %% [markdown]
# List

# %%
l = [10,20,30,40]
l
# Out:
# [10, 20, 30, 40]

# %%
l.append (50)
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l[0] = 11
l
# Out:
# [11, 20, 30, 40]

# %%
l = [10,'test1234', 'mest', [40,10], 123]
l
# Out:
# [10, 'test1234', 'mest', [40, 10], 123]

# %%
l[0]
# Out:
# 10

# %%
l[-1]
# Out:
# 123

# %%
len(l)
# Out:
# 5

# %%
l = [10, 'test', 'mest', 40]
l
# Out:
# [10, 'test', 'mest', 40]

# %%
l[-2]
# Out:
# 'mest'

# %%
l = ['data1.csv', 'data2.csv', 'data3.csv']

# %% [markdown]
# Tuple

# %%
t = (10, 12, 13)

# %% [markdown]
# Set

# %%
my_list = [1, 2, 3, 4, 5, 5, 5, 5, 5,5]
my_list
# Out:
# [1, 2, 3, 4, 5, 5, 5, 5, 5, 5]

# %%
my_set = set (my_list)
my_set
# Out:
# {1, 2, 3, 4, 5}

# %%
a = {1,2,3,4,5}
b = {4,5,6,7,8}

# %%
a.intersection(b)
# Out:
# {4, 5}

# %% [markdown]
# Dictionary

# %%
# key value pairs
customers = {
            'Alice': 25,
            'Bob': 30,
            'Charlie': 35
            }

# %%
customers['Alice']=30

# %%
customers
# Out:
# {'Alice': 30, 'Bob': 30, 'Charlie': 35}

# %%
customer = {'name': 'Alice', 'age': 30, 'city':'New York'}
customer['State'] ='NY'
customer['Segment'] ='Premium'

# %%
customer1 = customer
customer1
# Out:
# {'name': 'Alice',
#  'age': 30,
#  'city': 'New York',
#  'State': 'NY',
#  'Segment': 'Premium'}

# %%
#Bob
customer2 = {'name': 'Bob', 'age': 25, 'city':'Los Angeles', 'State': 'CA', 'Segment':'Standard'}

# %%
#Armen
customer3 = {'name': 'Charlie', 'age': 28, 'city':'Chicago', 'State': 'IL'}

# %%
list_of_customers = [customer1, customer2, customer3]

# %%
list_of_customers
# Out:
# [{'name': 'Alice',
#   'age': 30,
#   'city': 'New York',
#   'State': 'NY',
#   'Segment': 'Premium'},
#  {'name': 'Bob',
#   'age': 25,
#   'city': 'Los Angeles',
#   'State': 'CA',
#   'Segment': 'Standard'},
#  {'name': 'Charlie', 'age': 28, 'city': 'Chicago', 'State': 'IL'}]

# %%
list_of_customers[0].keys()
# Out:
# dict_keys(['name', 'age', 'city', 'State', 'Segment'])

# %%
l = [10,20,30,40]
d = {'key', 'Value'}

# %% [markdown]
# Pandas

# %%
import pandas as pd

# %%
data = {'name': ['Alice', 'Bob', 'Charlie', 'Armen', 'David'],
        'age': [30, 25, 28, 35, 42],
        'city': ['New York', 'Los Angeles', 'Chicago', 'Boston', 'San Francisco'],
        'revenue': [10000, 15000, 12000, 20000, 18000],
        'segment': ['Premium', 'Premium', 'Premium', 'Standard','Premium']}

# %%
data ['name']
data ['age']
# Out:
# [30, 25, 28, 35, 42]

# %%
df = pd.DataFrame(data)

# %%
df_filtered=df[df['age']>30]
df_filtered
# Out:
#     name  age           city
# 3  Armen   35         Boston
# 4  David   42  San Francisco

# %%
df.loc[df['revenue']>15000, 'segment']='High Revenue'

# %%
df.head()
# Out:
#       name  age           city  revenue       segment
# 0    Alice   30       New York    10000       Premium
# 1      Bob   25    Los Angeles    15000       Premium
# 2  Charlie   28        Chicago    12000       Premium
# 3    Armen   35         Boston    20000  High Revenue
# 4    David   42  San Francisco    18000  High Revenue
