# %% [markdown]
# Dates

# %%
from datetime import datetime, date, timedelta

# %%
my_date = date(year=2026, month=4, day=25)

# %%
type(my_date)
# Out:
# datetime.date

# %%
my_time = datetime(year=2026, month=4, day=25, hour=14)

# %%
my_time
# Out:
# datetime.datetime(2026, 4, 25, 14, 0)

# %%
today = date.today()
today
# Out:
# datetime.date(2026, 5, 4)

# %%
now = datetime.now()
now
# Out:
# datetime.datetime(2026, 5, 4, 21, 32, 36, 12638)

# %%
my_date.strftime("%Y-%m-%d")
# Out:
# '2026-04-25'

# %%
my_date.strftime("%Y/%m/%d")
# Out:
# '2026/04/25'

# %%
my_date.strftime("%B %d, %Y")
# Out:
# 'April 25, 2026'

# %%
start_date = my_date
end_date = date(2026,6,6)

# %%
delta = end_date - my_date
delta
# Out:
# datetime.timedelta(days=42)

# %%
end_date + timedelta(weeks=1)
# Out:
# datetime.date(2026, 6, 13)

# %%
rd = (today + timedelta(days=5)).strftime("%b %d %y")
rd
# Out:
# 'May 09 26'

# %%
user = 'Davit'
email_content = f"""Dear {user},

Please find the attached report.
Kindly note that the reporting date is {rd}

Best regards,
Ani
"""

email_content
# Out:
# 'Dear Davit,\n\nPlease find the attached report.\nKindly note that the reporting date is May 09 26\n\nBest regards,\nAni\n'

# %% [markdown]
# Dates with Pandas

# %%
import pandas as pd

df_dates = pd.DataFrame({
    "customer_id": [101, 102, 103, 104, 105],
    "signup_date": ["2024-01-15", "2024-02-20", "2024-03-05", "2024-03-18", "2024-04-10"],
    "last_purchase": ["2024-06-01", "2024-06-15", "2024-07-01", "2024-07-08", "2024-07-12"]
})

df_dates
# Out:
#    customer_id signup_date last_purchase
# 0          101  2024-01-15    2024-06-01
# 1          102  2024-02-20    2024-06-15
# 2          103  2024-03-05    2024-07-01
# 3          104  2024-03-18    2024-07-08
# 4          105  2024-04-10    2024-07-12

# %%
df_dates.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    5 non-null      int64
#  1   signup_date    5 non-null      str
#  2   last_purchase  5 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 352.0 bytes

# %%
df_dates['signup_date'] = pd.to_datetime(df_dates['signup_date'])
df_dates['last_purchase'] = pd.to_datetime(df_dates['last_purchase'])

# %%
df_dates.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    5 non-null      int64
#  1   signup_date    5 non-null      datetime64[us]
#  2   last_purchase  5 non-null      datetime64[us]
# dtypes: datetime64[us](2), int64(1)
# memory usage: 252.0 bytes

# %%
df_dates.to_csv('../data/test.csv', index=False)

# %%
test = pd.read_csv('../data/test.csv', parse_dates=['signup_date',
                                                  'last_purchase'],
                                                  dtype={'customer_id':str})
test.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    5 non-null      str
#  1   signup_date    5 non-null      datetime64[us]
#  2   last_purchase  5 non-null      datetime64[us]
# dtypes: datetime64[us](2), str(1)
# memory usage: 267.0 bytes

# %%
df_dates["signup_year"] = df_dates["signup_date"].dt.year
df_dates["signup_month"] = df_dates["signup_date"].dt.month
df_dates["signup_day"] = df_dates["signup_date"].dt.day
df_dates
# Out:
#    customer_id signup_date last_purchase  signup_year  signup_month  \
# 0          101  2024-01-15    2024-06-01         2024             1
# 1          102  2024-02-20    2024-06-15         2024             2
# 2          103  2024-03-05    2024-07-01         2024             3
# 3          104  2024-03-18    2024-07-08         2024             3
# 4          105  2024-04-10    2024-07-12         2024             4
#
#    signup_day
# 0          15
# 1          20
# 2           5
# 3          18
# 4          10

# %%
#df_dates["signup_date_name"] = df_dates['signup_date'].dt.month_name()
df_dates["signup_month_name"] = df_dates['signup_date'].dt.month_name()
df_dates["signup_day_name"] = df_dates['signup_date'].dt.day_name()
df_dates["days_count"] = df_dates['signup_date'].dt.days_in_month
df_dates["signup_dow"] = df_dates['signup_date'].dt.dayofweek

# %%
df_dates = df_dates.drop(columns=['signup_date_name'])

# %%
df_dates = df_dates.drop(columns=['days_in_month'])

# %%
df_dates
# Out:
#    customer_id signup_date last_purchase  signup_year  signup_month  \
# 0          101  2024-01-15    2024-06-01         2024             1
# 1          102  2024-02-20    2024-06-15         2024             2
# 2          103  2024-03-05    2024-07-01         2024             3
# 3          104  2024-03-18    2024-07-08         2024             3
# 4          105  2024-04-10    2024-07-12         2024             4
#
#    signup_day signup_month_name signup_day_name  days_count  signup_dow
# 0          15           January          Monday          31           0
# 1          20          February         Tuesday          29           1
# 2           5             March         Tuesday          31           1
# 3          18             March          Monday          31           0
# 4          10             April       Wednesday          30           2

# %%
df_dates["is_weekend"] = (df_dates['signup_date'].dt.day_of_week>=5).astype(int)

# %%
df_dates['days_between_signup_purchase'] = (df_dates['last_purchase'] - df_dates['signup_date']).dt.days

# %%
df_dates[df_dates['signup_date']>='2023']
# Out:
#    customer_id signup_date last_purchase  signup_year  signup_month  \
# 0          101  2024-01-15    2024-06-01         2024             1
# 1          102  2024-02-20    2024-06-15         2024             2
# 2          103  2024-03-05    2024-07-01         2024             3
# 3          104  2024-03-18    2024-07-08         2024             3
# 4          105  2024-04-10    2024-07-12         2024             4
#
#    signup_day signup_month_name signup_day_name  days_count  signup_dow  \
# 0          15           January          Monday          31           0
# 1          20          February         Tuesday          29           1
# 2           5             March         Tuesday          31           1
# 3          18             March          Monday          31           0
# 4          10             April       Wednesday          30           2
#
#    is_weekend  days_between_signup_purchase
# 0           0                           138
# ...

# %%
df_dates.sort_values('signup_date')
# Out:
#    customer_id signup_date last_purchase  signup_year  signup_month  \
# 0          101  2024-01-15    2024-06-01         2024             1
# 1          102  2024-02-20    2024-06-15         2024             2
# 2          103  2024-03-05    2024-07-01         2024             3
# 3          104  2024-03-18    2024-07-08         2024             3
# 4          105  2024-04-10    2024-07-12         2024             4
#
#    signup_day signup_month_name signup_day_name  days_count  signup_dow  \
# 0          15           January          Monday          31           0
# 1          20          February         Tuesday          29           1
# 2           5             March         Tuesday          31           1
# 3          18             March          Monday          31           0
# 4          10             April       Wednesday          30           2
#
#    is_weekend  days_between_signup_purchase
# 0           0                           138
# ...

# %%
df_dates.sort_values('signup_date', ascending=False)
# Out:
#    customer_id signup_date last_purchase  signup_year  signup_month  \
# 4          105  2024-04-10    2024-07-12         2024             4
# 3          104  2024-03-18    2024-07-08         2024             3
# 2          103  2024-03-05    2024-07-01         2024             3
# 1          102  2024-02-20    2024-06-15         2024             2
# 0          101  2024-01-15    2024-06-01         2024             1
#
#    signup_day signup_month_name signup_day_name  days_count  signup_dow  \
# 4          10             April       Wednesday          30           2
# 3          18             March          Monday          31           0
# 2           5             March         Tuesday          31           1
# 1          20          February         Tuesday          29           1
# 0          15           January          Monday          31           0
#
#    is_weekend  days_between_signup_purchase
# 4           0                            93
# ...

# %%
list(pd.date_range(start="2024-07-01", periods=7, freq="D"))
# Out:
# [Timestamp('2024-07-01 00:00:00'),
#  Timestamp('2024-07-02 00:00:00'),
#  Timestamp('2024-07-03 00:00:00'),
#  Timestamp('2024-07-04 00:00:00'),
#  Timestamp('2024-07-05 00:00:00'),
#  Timestamp('2024-07-06 00:00:00'),
#  Timestamp('2024-07-07 00:00:00')]

# %%
import pandas as pd

some_date = pd.Timestamp("2024-07-15")

print(f"Original date: {some_date}")
print(f"Beginning of month: {some_date.to_period('M').start_time}")
print(f"End of month: {some_date.to_period('M').end_time}")
# Out:
# Original date: 2024-07-15 00:00:00
# Beginning of month: 2024-07-01 00:00:00
# End of month: 2024-07-31 23:59:59.999999

# %%
df_dates['bom'] = df_dates['signup_date'].dt.to_period('M').dt.start_time
df_dates['eom'] = df_dates['signup_date'].dt.to_period('M').dt.end_time

# %%
df_dates['signup_date'].dt.to_period('M').dt.start_time.dt.date
# Out:
# 0    2024-01-01
# 1    2024-02-01
# 2    2024-03-01
# 3    2024-03-01
# 4    2024-04-01
# Name: signup_date, dtype: object
